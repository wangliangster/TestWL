# %% [markdown]
# # 结合新闻语料库和Wiki语料库模型，找到与”说“相近的100个词。
# ## 再加之人工鉴别删选出50个可表达观点的谓词列表ExpWords
# ## 可根据经验反馈，添加

# %%
ExpWords= ['表示','指出','认为','坦言','透露','介绍','明说','说','强调','提到','说道','称','声称','建议','呼吁','提及','直言','普遍认为','批评','重申','提出',
 '明确指出','觉得','宣称','猜测','特别强调','写道','相信','解释','谈到','深知','称赞','感慨','主张','还称','指责','披露','明确提出','描述','提醒','深有体会','爆料',
 '裁定','宣布','嘲讽','暗讽','留言','阐述','坚称','讲','问','说过']

# %%
len(set(ExpWords))
# Out:
# 52

# %% [markdown]
# ### 分句，调用pyltp的SentenceSplitter，优于用正则表达式

# %%
from pyltp import SentenceSplitter
def split_sentences(string):
    stentences=list(SentenceSplitter.split(string))
    return stentences

# %%
New1='''
中新社北京1月7日电 (郭超凯)中国探月工程官方微信7日发布消息称，嫦娥四号绕月时间之所以比嫦娥三号长，是因为嫦娥四号需要等待月昼充能量、发射窗口限制多以及需要在轨测试求精细。

中国探月工程官方微信表示，2018年12月8日2时23分，嫦娥四号探测器发射升空，2019年1月3日10时26分，嫦娥四号探测器成功软着陆在月球背面预选区域。嫦娥三号自发射到着陆月球用了13天，而嫦娥四号用了26天，这其中的科学原理基于三个方面：

一是嫦娥四号需要等待月昼充能量。月球自转的周期是28天，为了让探测器落到月球上就能得到充分的太阳光开展工作，因此就必须要让它在月球着陆区的白天着陆。而嫦娥四号近月制动之后，运行的轨道面到着陆区上方的时候正好是着陆区的晚上，因此嫦娥四号要持续绕月飞行一段时间，才能赶在月背的白天实施着陆。

二是嫦娥四号发射窗口限制多。为获取最大的运载能力，嫦娥四号的发射窗口要考虑很多约束条件，使其与日、地、月的相对关系满足任务需求。例如，奔月轨道需要调整近月点经度和飞行时间，让环月轨道临近着月点上空，为登月创造条件；奔月飞行过程中，要考虑太阳能帆板的受晒问题，要求太阳光入射方向与太阳帆板之间的夹角保持在一定范围内。此外在飞行和着陆过程中，还要考虑连续测控问题。其形成发射机会的交集只在2018年12月8日和9日各有2次，正所谓“过了这村就没这店”。


同时，嫦娥四号的工作需要“鹊桥”中继星的配合，对各自的发射时间给出了进一步的限制。因此，嫦娥四号之所以要在月球附近“等天亮”，很大程度上是由轨道与发射窗口的限制所决定的。

三是嫦娥四号需要在轨测试求精细。在这42万公里的行程中，嫦娥四号还要按需调整飞行速度和轨道机动参数，而且在接近月球的过程中，还会有相应的科研测试项目。嫦娥四号绕月期间一些设备需要开机进行测试，有足够的时间，才能让测试更完整，准备更充分。嫦娥四号进入环月轨道以来，进行了2次环月轨道修正，与“鹊桥”中继星进行了4次中继链路测试，开展了激光测距、三维成像、微波测距测速等导航敏感器在轨测试，为实施月球背面软着陆做好准备。(完)

'''

# %%
split_sentences(New1)
# Out:
# ['',
#  '中新社北京1月7日电 (郭超凯)中国探月工程官方微信7日发布消息称，嫦娥四号绕月时间之所以比嫦娥三号长，是因为嫦娥四号需要等待月昼充能量、发射窗口限制多以及需要在轨测试求精细。',
#  '',
#  '',
#  '中国探月工程官方微信表示，2018年12月8日2时23分，嫦娥四号探测器发射升空，2019年1月3日10时26分，嫦娥四号探测器成功软着陆在月球背面预选区域。',
#  '嫦娥三号自发射到着陆月球用了13天，而嫦娥四号用了26天，这其中的科学原理基于三个方面：',
#  '',
#  '一是嫦娥四号需要等待月昼充能量。',
#  '月球自转的周期是28天，为了让探测器落到月球上就能得到充分的太阳光开展工作，因此就必须要让它在月球着陆区的白天着陆。',
#  '而嫦娥四号近月制动之后，运行的轨道面到着陆区上方的时候正好是着陆区的晚上，因此嫦娥四号要持续绕月飞行一段时间，才能赶在月背的白天实施着陆。',
#  '',
#  '',
#  '二是嫦娥四号发射窗口限制多。',
#  '为获取最大的运载能力，嫦娥四号的发射窗口要考虑很多约束条件，使其与日、地、月的相对关系满足任务需求。',
#  '例如，奔月轨道需要调整近月点经度和飞行时间，让环月轨道临近着月点上空，为登月创造条件；',
#  '奔月飞行过程中，要考虑太阳能帆板的受晒问题，要求太阳光入射方向与太阳帆板之间的夹角保持在一定范围内。',
#  '此外在飞行和着陆过程中，还要考虑连续测控问题。',
#  '其形成发射机会的交集只在2018年12月8日和9日各有2次，正所谓“过了这村就没这店”。',
#  '',
#  '',
#  '',
#  '同时，嫦娥四号的工作需要“鹊桥”中继星的配合，对各自的发射时间给出了进一步的限制。',
#  '因此，嫦娥四号之所以要在月球附近“等天亮”，很大程度上是由轨道与发射窗口的限制所决定的。',
#  '',
#  '',
#  '三是嫦娥四号需要在轨测试求精细。',
#  '在这42万公里的行程中，嫦娥四号还要按需调整飞行速度和轨道机动参数，而且在接近月球的过程中，还会有相应的科研测试项目。',
#  '嫦娥四号绕月期间一些设备需要开机进行测试，有足够的时间，才能让测试更完整，准备更充分。',
# ...

# %%
import jieba
import re
def get_target_sentences(sentences,keywords):
    target_sentences=[]
    for sent in sentences:
        if sent:
            words=jieba.lcut(sent)
            for word in words:
                if word in keywords:
                    ### remove some special character such as "" \u0 tab to make it is able to be analysised by ltp_server
                    sent=''.join(re.findall('[\w\d|：:，,。!?！？\(\)·《》]+',sent)) 
                    target_sentences.append(sent)
                    break ## avoid repeat add sentence which have more than two words in keywords
    return target_sentences

# %%
get_target_sentences(split_sentences(New1),ExpWords)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /var/folders/f1/s02h7_c152xbsy1b3cq00pr80000gn/T/jieba.cache
# Loading model cost 0.676 seconds.
# Prefix dict has been built succesfully.
# ['中新社北京1月7日电(郭超凯)中国探月工程官方微信7日发布消息称，嫦娥四号绕月时间之所以比嫦娥三号长，是因为嫦娥四号需要等待月昼充能量发射窗口限制多以及需要在轨测试求精细。',
#  '中国探月工程官方微信表示，2018年12月8日2时23分，嫦娥四号探测器发射升空，2019年1月3日10时26分，嫦娥四号探测器成功软着陆在月球背面预选区域。']

# %% [markdown]
# 1. 要在本机启用ltp_server服务进程，挂在12345端口， （启动方法参见帮助说明）
# 2. 利用requests 和json获得json格式服务端分析数据，以此为基础进行后续处理
# 3. 未来可否把服务挂到云上---To Do
#
# ## Example

# %%
import requests as req
import json

# %%
res = req.post(url='http://127.0.0.1:12345/ltp',
data=str('f=json&t=all&s=要在本机启用ltp_server服务进程，挂在12345端口').encode('utf-8'))
res_obj = json.loads(res.text)

# %%
type(res_obj[0][0])
# Out:
# list

# %%
HED_obj =[word_obj for word_obj in res_obj[0][0] if word_obj['parent'] == -1 and word_obj['relate'] == 'HED'][0]

# %%
HED_obj
# Out:
# {'arg': [{'beg': 1, 'end': 1, 'id': 0, 'type': 'LOC'},
#   {'beg': 4, 'end': 8, 'id': 1, 'type': 'A1'}],
#  'cont': '启用',
#  'id': 3,
#  'ne': 'O',
#  'parent': -1,
#  'pos': 'v',
#  'relate': 'HED'}

# %%
SBV_obj = [word_obj for word_obj in res_obj[0][0] if word_obj['parent'] == HED_obj['id'] and word_obj['relate'] == 'SBV'][0]

# %% [markdown]
# SBV_obj

# %% [markdown]
# + 获得句子的NER和依赖分析结果 </br>
# - 根据依赖分析尝试找到Head，如果Head不属于目标词，舍弃该句子</br>
# * 根据依赖分析尝试找到主语（该主语为人，根据NER），如果找不到，舍弃该句子</br>
# + 保留主语的一个修饰语（ATT，定中关系）</br>

# %%
def get_speaker_and_viewpoint_from_ltp1(sentence):
    ltp_res = req.post('http://127.0.0.1:12345/ltp', data = str('f=json&t=all&s=' + sentence).encode('utf-8'))
    ltp_obj = json.loads(ltp_res.text)
    sent_ltp = ltp_obj[0][0]
    
    # get head index, if HED relation in Expwords, return index, or return 0 drop this sent
    head_index = -1
    # Default Head word
    Head_Word='说'
    for i in range(len(sent_ltp)):
        if sent_ltp[i]['parent'] == -1 and sent_ltp[i]['cont'] in ExpWords:
            head_index = i
            Head_Word = sent_ltp[i]['cont']
            break
    if head_index < 0:
        return 0
    
    head_word_obj = sent_ltp[head_index]    
    
    SBV_index = -1
    for i in range(len(sent_ltp)):
        if sent_ltp[i]['parent'] == head_word_obj['id'] and sent_ltp[i]['relate'] == 'SBV' and sent_ltp[i]['ne'] == 'S-Nh':
            SBV_index = i
            break
    if SBV_index < 0:
        return 0
    
    i = SBV_index - 1
    offset = 0
    # keep the first ATT for Speaker(S-Nh)
    while i >= 0 and sent_ltp[i]['relate'] == 'ATT':
        i -= 1
        offset += 1
        
    speaker = ''.join([word_obj['cont'] for word_obj in sent_ltp[SBV_index - offset: SBV_index + 1]])
    
    if len(sent_ltp) <= head_index + 1: return 0
    
    ### remove : something like 
    offset = 0
    if sent_ltp[head_index+1]['relate'] == 'WP':
        offset += 1

    viewpoint = ''.join([word_obj['cont'] for word_obj in sent_ltp[head_index + 1 + offset:]])
    return (speaker, Head_Word, viewpoint)

# %%
def get_news_speaker_and_viewpoints1(news_content):
    target_sentences = get_target_sentences(split_sentences(news_content),ExpWords)
    for sent in target_sentences:
        speaker_view = get_speaker_and_viewpoint_from_ltp1(sent)
        if speaker_view and speaker_view[2]:
            print('【' + speaker_view[0] + '】' +speaker_view[1]+': '+ speaker_view[2])

# %%
New2='''
网易科技讯12月21日消息，据国外媒体报道，继上周中国法院对苹果公司部分iPhone发布禁售令之后，当地时间周四德国慕尼黑一法院也对苹果部分iPhone产品发布了禁售令。苹果公司回应称，将停售德国商店的iPhone 7以及iPhone 8手机。但所有型号iPhone将在德国市场第三方零售商店有售。

 律师的情感里也有同情、人性的光辉。该辩护词不是在缕理法理，而是在填补法律与人性之间的沟壑。谢谢邓律师！该文可入经典。
 5 Reply by author
说的对，法律也应该有人情
 4
梧扬  置顶
 孝子
'''

# %%
get_news_speaker_and_viewpoints1(New5)
# Out:
# 【张扣扣】表示: 不服，当庭提出上诉。
# 【弗洛伊德】说: 过：人的创伤经历，特别是童年的创伤经历会对人的一生产生重要的影响。
# 【张扣扣】描述: 了他的心理经过：王三娃用木棒将我母亲一棒打死，我也在现场，当时我年龄还小，只有13岁，我就想拿着刀将王三娃弄死，最后被我爸爸拉住了，当时我看到我妈鼻子口里都是血，心里非常痛苦，我就发誓一定要给我妈报仇，我还大声说：我不报仇，我就是狗日的。
# 【朋友曾秋英】说: 他有很强的恋母情节。
# 【法史学者李德嘉】认为: 太宗通过此案宽赦了甄婆儿，做到了情法两尽。
# 【著名法学家朱苏力】认为: 不能简单的以一句依法治国给打发了。
# 【朱苏力】认为: 报复性反应是是任何生物在自然界生存竞争的基本需要和本能。
# 【张扣扣】解释: 道：是老二先挑起来的，是老二先打我妈的，王三娃是用棒把我妈打死的主要凶手，王校军是王三娃打死人之后打通层层关系的幕后操作人，王自新就是煽风点火的人，没有王自新说的打，往死里打，打死了老子顶到这句话我妈也不会死，所以我才要杀死王自新他们四个人。
# 【张扣扣】说: 与你们没有关系，你们不要参与。
# 【张扣扣】说: 我其实很随和的，生活中很少跟别人发生摩擦或者矛盾。

# %% [markdown]
# # 针对get_speaker_and_viewpoint_from_ltp1对某些新闻提不出观点，做了加强
# ## 能显示一些特殊的新闻如New3,New4, 但效果对其它并不一定效果更佳，有待继续研究---To Do

# %%
def get_speaker_and_viewpoint_from_ltp2(sentence):
    ltp_res = req.post('http://127.0.0.1:12345/ltp', data = str('f=json&t=all&s=' + sentence).encode('utf-8'))
    ltp_obj = json.loads(ltp_res.text)
    sent_ltp = ltp_obj[0][0]
    
    # get head and exist if not the target head word
    head_index = -1
    # Default Head Word
    Head_Word='说'
    for i in range(len(sent_ltp)):
        ### 不强调一定是核心关系(HED)
        if sent_ltp[i]['cont'] in ExpWords:
            head_index = i
            Head_Word = sent_ltp[i]['cont']
            break
    if head_index < 0:
        return 0
    head_word_obj = sent_ltp[head_index]    
    
    SBV_index = -1
    for i in range(len(sent_ltp)):
        # 找最近的主谓关系，不强调是NER的命名实体，这样如“网友”/“委员会”等就可以抽取了
        if sent_ltp[i]['parent'] == head_word_obj['id'] and sent_ltp[i]['relate'] == 'SBV':
            SBV_index = i
            break
    # 如果谓词没有SBV主语，全句找一个NER假设它就是观点表述人（有点猜的意思，待究）
    if SBV_index < 0:
        for i in range(len(sent_ltp)):
            if sent_ltp[i]['ne'] =='S-Nh':
                SBV_index =i
                break
    # 如果谓词没有SBV主语，全句也无一个NER实体，舍弃
    if SBV_index <0:return 0
    
    i = SBV_index - 1
    offset = 0
    while i >= 0 and sent_ltp[i]['relate'] == 'ATT':
        i -= 1
        offset += 1
    speaker = ''.join([word_obj['cont'] for word_obj in sent_ltp[SBV_index - offset: SBV_index + 1]])
    
    ###只有一个谓词独立成句，舍弃
    if len(sent_ltp) <= head_index+1: return 0
    
    ###去掉谓词紧接邻的符号如:," 等
    offset = 0
    #print("len:{} hedI:{} sent:{}".format(len(sent_ltp),head_index,sentence))
    if sent_ltp[head_index+1]['relate'] == 'WP':
        offset += 1

    viewpoint = ''.join([word_obj['cont'] for word_obj in sent_ltp[head_index +1 + offset:]])
    return (speaker, Head_Word, viewpoint)

# %%
def get_news_speaker_and_viewpoints2(news_content):
    target_sentences = get_target_sentences(split_sentences(news_content),ExpWords)
    for sent in target_sentences:
        speaker_view = get_speaker_and_viewpoint_from_ltp2(sent)
        if speaker_view and speaker_view[2]:
            print('【' + speaker_view[0] + '】' +speaker_view[1]+': '+ speaker_view[2])

# %%
get_news_speaker_and_viewpoints2(New1)
# Out:
# 【郭超凯】称: 嫦娥四号绕月时间之所以比嫦娥三号长，是因为嫦娥四号需要等待月昼充能量发射窗口限制多以及需要在轨测试求精细。
# 【中国探月工程官方微信】表示: 2018年12月8日2时23分，嫦娥四号探测器发射升空，2019年1月3日10时26分，嫦娥四号探测器成功软着陆在月球背面预选区域。

# %%
get_news_speaker_and_viewpoints2(New2)
# Out:
# 【苹果公司】称: 将停售德国商店的iPhone7以及iPhone8手机。
# 【苹果】表示: 计划对这项裁决提出上诉。
# 【法官马提亚·齐根】说: 在这种情况下，这项裁决不会立即生效。
# 【苹果公司】表示: 在整个上诉过程中，其将不会在位于德国的15家苹果零售商店销售iPhone7和iPhone8手机。
# 【苹果】表示: 所有型号的iPhone仍将通过德国的运营商和其他第三方零售商销售。
# 【高通】表示: 禁令将在其正式发布后立即生效。
# 【该公司】表示: 将在几天内完成这一过程。
# 【其】提出: 过类似申请。
# 【法官】裁定: 搭载英特尔和苹果供应商Qorvo芯片的手机侵犯了高通一项围绕所谓封包追踪技术(envelopetracking)的专利。
# 【苹果】表示: 高通的行动是孤注一掷的尝试，目的是为了转移人们对两家公司之间真正问题的注意力。
# 【Qorvo首席知识产权律师迈克·贝克】说: 我们确信，我们的封包追踪技术芯片在诉讼中没有侵犯专利，如果法庭认真考量了所有证据，就会得出不同的结论。
# 【英特尔总法律顾问史蒂芬·罗杰斯】表示: 高通的目标不是维护自己的知识产权，而是排斥高端调制解调器芯片市场的竞争，并捍卫一种最终会损害消费者利益的商业模式。
# 【丹·罗森博格DonRosenberg】表示: 过去两周，不同司法管辖区的两家权威法院已经证实了高通专利的价值，并宣布苹果是侵权者，并在德国和中国这两个重要市场上发布了针对部分iPhone手机的禁售令。

# %%
get_news_speaker_and_viewpoints2(New3)
# Out:
# 【李丽珍】留言: 国峰是我的教练，目标是人鱼线，今日是第一天，哈哈哈哈哈哈。
# 【网友】说: 有国峰帮忙一定成功，还很期待见到珍妹的腹肌！

# %%
get_news_speaker_and_viewpoints2(New4)
# Out:
# 【他们】认为: 党的十九大以来全面从严治党取得了新的重大成果，深得党心民心，这些成果来之不易，要格外珍惜。
# 【他们】认为: 党在长期执政条件下实现自我净化自我完善自我革新自我提高的这些宝贵经验，必须一以贯之长期坚持。
# 【习近平总书记】提出: 六项任务，对以全面从严治党巩固党的团结统一为决胜全面建成小康社会提供坚强保障作出战略部署，发出了强有力的动员令。
# 【与会委员】认为: 党要管党必须从党内政治生活管起，从严治党必须从党内政治生活严起，把自己摆进去，身体力行，以上率下，为贯彻新形势下党内政治生活若干准则作出榜样。
# 【他们】认为: 习近平总书记的重要讲话既直面问题，又充满自信，饱含了许党许国的担当精神和质朴的人民情怀，催人奋进。

# %%
get_news_speaker_and_viewpoints1(New4)

# %%
get_news_speaker_and_viewpoints2(New5)
# Out:
# 【张扣扣】表示: 不服，当庭提出上诉。
# 【我】阐述: 辩护观点之前，请先允许我对逝去的三条生命致以最诚挚的哀悼，对被害人家属表示最深切的同情和慰问。
# 【弗洛伊德】说: 过：人的创伤经历，特别是童年的创伤经历会对人的一生产生重要的影响。
# 【张扣扣】描述: 了他的心理经过：王三娃用木棒将我母亲一棒打死，我也在现场，当时我年龄还小，只有13岁，我就想拿着刀将王三娃弄死，最后被我爸爸拉住了，当时我看到我妈鼻子口里都是血，心里非常痛苦，我就发誓一定要给我妈报仇，我还大声说：我不报仇，我就是狗日的。
# 【张扣扣一家三口】认为: 这个判决太轻了。
# 【张扣扣】说: 王三娃被判处有期徒刑7年，表面上是受到制裁判决了，但实际上是轻判了。
# 【张扣扣】说: 王自新家将我妈杀了，既没有偿命，又没有偿钱，我要收拾他们。
# 【张扣扣】说: 在过去的22年中，王自新一家人始终没有给我们家道歉沟通过，也没有经济赔偿，这22年的仇恨在我的心里越来越严重，我就想把王自新他们一家人杀死给妈报仇，为了报仇我连媳妇和娃都没有要，我心里想的就是为了报仇，如果这些年王自新一家愿意给我们赔礼道歉，我也不会发生今天杀人的悲剧。
# 【张扣扣】说: 张扣扣社会融入过程极其不顺利，社会支持系统长期缺位，加剧了他内心的痛苦脆弱和孤立无援。
# 【朋友曾秋英】说: 他有很强的恋母情节。
# 【鲁迅先生】说: 过不在沉默中爆发，就在沉默中灭亡。
# 【法史学者李德嘉】认为: 太宗通过此案宽赦了甄婆儿，做到了情法两尽。
# 【著名法学家朱苏力】认为: 不能简单的以一句依法治国给打发了。
# 【朱苏力】认为: 报复性反应是是任何生物在自然界生存竞争的基本需要和本能。
# 【张扣扣】解释: 道：是老二先挑起来的，是老二先打我妈的，王三娃是用棒把我妈打死的主要凶手，王校军是王三娃打死人之后打通层层关系的幕后操作人，王自新就是煽风点火的人，没有王自新说的打，往死里打，打死了老子顶到这句话我妈也不会死，所以我才要杀死王自新他们四个人。
# 【张扣扣】说: 与你们没有关系，你们不要参与。
# 【张扣扣】说: 我等了22年，我妈的仇终于报了，并在村道上举起两只手边走边说：等了22年，终于给妈妈报仇了
# ...

# %% [markdown]
# # 文件形式输入方式分析

# %%
def get_viewpoints1(news_file):
    with open(news_file,mode='r',encoding='utf-8') as file:
        content = file.read()
    get_news_speaker_and_viewpoints1(content)

# %%
def get_viewpoints2(news_file):
    with open(news_file,mode='r',encoding='utf-8') as file:
        content = file.read()
    get_news_speaker_and_viewpoints2(content)

# %%
get_viewpoints1('news1.txt')
# Out:
# 【孟晚舟】表示: 自己的工作没想到会以这样的形式得到回报：这份回报以一个普通日本人的来信展现在我面前，让我的心里充满了无比的自豪与宽慰。

# %%
get_viewpoints2('news1.txt')
# Out:
# 【孟晚舟】提及: 了初次去日本的感受。
# 【孟晚舟】表示: 自己的工作没想到会以这样的形式得到回报：这份回报以一个普通日本人的来信展现在我面前，让我的心里充满了无比的自豪与宽慰。
# 【大使馆】表示: 要求立刻恢复孟晚舟人身自由。
# 【华为方面】称: 孟晚舟在加拿大转机时被加拿大当局代表美国政府暂时扣留，华为相信法律体系最终给出公正结论。
# 【法官】表示: 11日继续举行。
# 【法官】宣布: 准许孟晚舟女士获得保释。
# 【律师】说: 他从业四十几年，还从来没见过，这样愿意为陌生人担保的事。

# %% [markdown]
# # ltp_server 启动方法
# + cp -fr ltp_data_v3.4.0 /Users/liang/Documents/GitHub/pyltp/ltp/bin/ltp_data
# + /Users/liang/Documents/GitHub/pyltp/ltp/bin/ltp_server
# ## 保持后台运行

# %% [markdown]
# # 不用CS结构，借助json数据格式进行分析（这样速度似乎很慢）
# ## 全用python 接口方式实现，TO DO
# + 以下是python 调用分句，分词，NER，DP，SRL的example

# %%
import sys, os

# ROOTDIR = os.path.join(os.path.dirname(__file__), os.pardir)
# sys.path = [os.path.join(ROOTDIR, "lib")] + sys.path
#print("rootdir:",ROOTDIR)
#print("sys.path:",sys.path)
# Set your own model path
# MODELDIR=os.path.join(ROOTDIR, "./ltp_data_v3.4.0")
MODELDIR='/Users/liang/Documents/GitHub/pyltp/ltp_data_v3.4.0'
#print(MODELDIR)
from pyltp import SentenceSplitter, Segmentor, Postagger, Parser, NamedEntityRecognizer, SementicRoleLabeller

paragraph = '中国进出口银行与中国银行加强合作。中国进出口银行与中国建设银行也加强合作！'

sentence = SentenceSplitter.split(paragraph)[0]

segmentor = Segmentor()
segmentor.load(os.path.join(MODELDIR, "cws.model"))
words = segmentor.segment(sentence)
print("\t".join(words))

postagger = Postagger()
postagger.load(os.path.join(MODELDIR, "pos.model"))
postags = postagger.postag(words)
# list-of-string parameter is support in 0.1.5
# postags = postagger.postag(["中国","进出口","银行","与","中国银行","加强","合作"])
print("\t".join(postags))

parser = Parser()
parser.load(os.path.join(MODELDIR, "parser.model"))
arcs = parser.parse(words, postags)
# for arc in arcs:
#     print(arc.relation)
print("\t".join("%d:%s" % (arc.head, arc.relation) for arc in arcs))

recognizer = NamedEntityRecognizer()
recognizer.load(os.path.join(MODELDIR, "ner.model"))
netags = recognizer.recognize(words, postags)
print("\t".join(netags))

labeller = SementicRoleLabeller()
labeller.load(os.path.join(MODELDIR, "pisrl.model"))
roles = labeller.label(words, postags, arcs)

for role in roles:
    print(role.index, "".join(
            ["%s:(%d,%d)" % (arg.name, arg.range.start, arg.range.end) for arg in role.arguments]))

segmentor.release()
postagger.release()
parser.release()
recognizer.release()
labeller.release()
# Out:
# 中国	进出口	银行	与	中国银行	加强	合作	。
# ns	v	n	p	ni	v	v	wp
# 3:ATT	3:ATT	6:SBV	6:ADV	4:POB	0:HED	6:VOB	6:WP
# B-Ni	I-Ni	E-Ni	O	S-Ni	O	O	O
# 5 A0:(0,2)A1:(6,6)
